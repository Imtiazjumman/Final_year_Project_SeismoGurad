# %% [markdown]
# ## Team Members Name
# MD. Atiqur Rahman Sifat
# Id- 0432410005101124
#
# Muhammad Imtiaz Ahmed
# Id-0432410005101138
#
# Labib Ahmod
# Id- 0432410005101133
#
# Fahimda Fardousi
# Id- 2215151132

# %%
# Section 1: Library imports

import h5py 
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.metrics import confusion_matrix, classification_report, roc_curve, auc
from sklearn.model_selection import train_test_split  

# TensorFlow / Keras building blocks
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import (
    Conv1D, MaxPooling1D, Flatten, Dense,
    BatchNormalization, Dropout,
    Bidirectional, LSTM,
    GlobalAveragePooling1D,
    Input
)
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.regularizers import l2  # Weight-decay regularisation

# %%
# Section 2: Load & inspect the metadata CSV
meta = pd.read_csv("chunk2.csv", low_memory=False)
print(f"Total records loaded: {len(meta):,}")
print(meta.head())
# Out:
# Total records loaded: 200,000
#   network_code receiver_code receiver_type  receiver_latitude  \
# 0           TA          109C            BH            32.8889
# 1           TA          109C            BH            32.8889
# 2           TA          109C            BH            32.8889
# 3           TA          109C            BH            32.8889
# 4           TA          109C            BH            32.8889
#
#    receiver_longitude  receiver_elevation_m  p_arrival_sample p_status  \
# 0           -117.1051                 150.0             700.0   manual
# 1           -117.1051                 150.0             600.0   manual
# 2           -117.1051                 150.0             500.0   manual
# 3           -117.1051                 150.0             900.0   manual
# 4           -117.1051                 150.0             700.0   manual
#
#    p_weight  p_travel_sec  ...  source_magnitude_author  \
# 0       0.5     17.080000  ...                      NaN
# 1       0.5     16.879999  ...                      NaN
# 2       0.5     17.260000  ...                      NaN
# 3       0.5     17.280001  ...                      NaN
# 4       0.5     18.139999  ...                      NaN
#
#   source_mechanism_strike_dip_rake  source_distance_deg source_distance_km  \
# 0                              NaN                 0.92             102.09
# 1                              NaN                 0.91             101.34
# 2                              NaN                 0.92             101.87
# 3                              NaN                 0.93             103.26
# 4                              NaN                 0.92             102.48
#
#   back_azimuth_deg                                 snr_db  coda_end_sample  \
# 0            159.3  [56.79999924 55.40000153 47.40000153]        [[2896.]]
# 1            281.7  [65.         65.5        61.40000153]        [[5508.]]
# 2            280.5  [37.20000076 42.         38.59999847]        [[3114.]]
# 3            281.6  [54.09999847 54.90000153 45.5       ]        [[3152.]]
# 4              4.7  [58.20000076 56.20000076 53.79999924]        [[3134.]]
#
#              trace_start_time    trace_category                 trace_name
# 0  2006-07-23 15:59:00.960000  earthquake_local  109C.TA_20060723155859_EV
# 1  2006-11-03 15:56:53.610000  earthquake_local  109C.TA_20061103155652_EV
# 2  2006-11-03 16:12:24.700000  earthquake_local  109C.TA_20061103161223_EV
# 3  2006-11-14 13:32:22.540000  earthquake_local  109C.TA_20061114133221_EV
# 4  2006-11-27 10:46:41.060000  earthquake_local  109C.TA_20061127104640_EV
#
# [5 rows x 35 columns]

# %%
print(meta.info())
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 200000 entries, 0 to 199999
# Data columns (total 35 columns):
#  #   Column                            Non-Null Count   Dtype
# ---  ------                            --------------   -----
#  0   network_code                      200000 non-null  str
#  1   receiver_code                     200000 non-null  str
#  2   receiver_type                     200000 non-null  str
#  3   receiver_latitude                 200000 non-null  float64
#  4   receiver_longitude                200000 non-null  float64
#  5   receiver_elevation_m              200000 non-null  float64
#  6   p_arrival_sample                  200000 non-null  float64
#  7   p_status                          200000 non-null  str
#  8   p_weight                          199937 non-null  float64
#  9   p_travel_sec                      200000 non-null  float64
#  10  s_arrival_sample                  200000 non-null  float64
#  11  s_status                          200000 non-null  str
#  12  s_weight                          199943 non-null  float64
#  13  source_id                         200000 non-null  str
#  14  source_origin_time                200000 non-null  str
#  15  source_origin_uncertainty_sec     17254 non-null   float64
#  16  source_latitude                   200000 non-null  float64
#  17  source_longitude                  200000 non-null  float64
#  18  source_error_sec                  83926 non-null   float64
#  19  source_gap_deg                    82710 non-null   float64
#  20  source_horizontal_uncertainty_km  80211 non-null   float64
#  21  source_depth_km                   199991 non-null  float64
#  22  source_depth_uncertainty_km       71069 non-null   float64
#  23  source_magnitude                  200000 non-null  float64
#  24  source_magnitude_type             200000 non-null  str
#  25  source_magnitude_author           64709 non-null   str
#  26  source_mechanism_strike_dip_rake  1153 non-null    str
#  27  source_distance_deg               200000 non-null  float64
#  28  source_distance_km                200000 non-null  float64
#  29  back_azimuth_deg                  200000 non-null  float64
#  30  snr_db                            200000 non-null  str
#  31  coda_end_sample                   200000 non-null  str
#  32  trace_start_time                  200000 non-null  str
#  33  trace_category                    200000 non-null  str
#  34  trace_name                        200000 non-null  str
# dtypes: float64(20), str(15)
# memory usage: 53.4 MB
# None

# %%
# Section 3: Filter to 'earthquake_local' category

meta = meta[meta["trace_category"] == "earthquake_local"]
meta = meta.dropna(subset=["p_arrival_sample"])
meta["p_arrival_sample"] = meta["p_arrival_sample"].astype(int)

print(f"Usable traces after filtering: {len(meta):,}")
print(f"Unique seismic events: {meta['source_id'].nunique():,}")
# Out:
# Usable traces after filtering: 200,000
# Unique seismic events: 101,395

# %%
# Section 4: Event-level train / test split

unique_events = meta["source_id"].unique()

train_events, test_events = train_test_split(
    unique_events,
    test_size=0.15,
    random_state=42
)

train_meta = meta[meta["source_id"].isin(train_events)]
test_meta = meta[meta["source_id"].isin(test_events)]

print(f"Training samples: {len(train_meta):,}")
print(f"Test samples: {len(test_meta):,}")
# Out:
# Training samples: 170,093
# Test samples: 29,907

# %%
# Section 5: Waveform extraction & pre-processing

def create_dataset(df, hdf5_path="chunk2.hdf5", window=800):
    X, y = [], []

    with h5py.File(hdf5_path, "r") as f:
        available_traces = set(f["data"].keys())

        for row in df.itertuples(index=False):
            try:
                trace = row.trace_name

                if trace not in available_traces:
                    continue

                p = int(row.p_arrival_sample)

                if p < 1600:
                    continue

                data = f["data"][trace][:]
                z = data[:, 2]

                noise = z[p - 1600 : p - 800]
                p_wave = z[p - 400 : p + 400]

                for signal, label in [(noise, 0), (p_wave, 1)]:
                    if len(signal) != window:
                        continue

                    std = np.std(signal)
                    if std < 1e-10:  
                        continue
                    
                    signal = (signal - np.mean(signal)) / std

                    X.append(signal)
                    y.append(label)

            except Exception:
                continue

    return np.array(X, dtype=np.float32), np.array(y, dtype=np.int32)

# %%
# Section 6: Build the train / test arrays

X_train, y_train = create_dataset(train_meta)
X_test, y_test = create_dataset(test_meta)

X_train = X_train[..., np.newaxis]
X_test = X_test[..., np.newaxis]

print(f"X_train shape: {X_train.shape} | class balance: {np.bincount(y_train)}")
print(f"X_test shape: {X_test.shape} | class balance: {np.bincount(y_test)}")
# Out:
# X_train shape: (54, 800, 1) | class balance: [27 27]
# X_test shape: (12, 800, 1) | class balance: [6 6]

# %%
# Section 7: Shared training callbacks

def get_callbacks(patience_stop=8, patience_lr=4, min_lr=1e-7):
    return [
        EarlyStopping(
            monitor='val_loss',
            patience=patience_stop,
            restore_best_weights=True,
            verbose=1
        ),
        ReduceLROnPlateau(
            monitor='val_loss',
            factor=0.5,
            patience=patience_lr,
            min_lr=min_lr,
            verbose=1
        )
    ]

# %%
# Section 8: Model 1 - Baseline CNN

model1 = Sequential([
    Conv1D(32, 7, activation='relu', input_shape=(800, 1), padding='same'),
    BatchNormalization(),
    MaxPooling1D(2),
    Dropout(0.2),

    Conv1D(64, 5, activation='relu', padding='same'),
    BatchNormalization(),
    MaxPooling1D(2),
    Dropout(0.25),

    Conv1D(128, 3, activation='relu', padding='same'),
    BatchNormalization(),
    MaxPooling1D(2),
    Dropout(0.3),

    Flatten(),
    Dense(128, activation='relu', kernel_regularizer=l2(1e-4)),
    BatchNormalization(),
    Dropout(0.4),
    Dense(1, activation='sigmoid')
], name='Baseline_CNN')

model1.compile(
    optimizer=Adam(learning_rate=0.0005),
    loss='binary_crossentropy',
    metrics=['accuracy']
)

model1.summary()
# Out:
# WARNING:tensorflow:TensorFlow GPU support is not available on native Windows for TensorFlow >= 2.11. Even if CUDA/cuDNN are installed, GPU will not be used. Please use WSL2 or the TensorFlow-DirectML plugin.
# c:\Users\ASUS\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\convolutional\base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "Baseline_CNN"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv1d (Conv1D)                 │ (None, 800, 32)        │           256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 800, 32)        │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling1d (MaxPooling1D)    │ (None, 400, 32)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 400, 32)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_1 (Conv1D)               │ (None, 400, 64)        │        10,304 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 400, 64)        │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling1d_1 (MaxPooling1D)  │ (None, 200, 64)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 200, 64)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_2 (Conv1D)               │ (None, 200, 128)       │        24,704 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_2           │ (None, 200, 128)       │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling1d_2 (MaxPooling1D)  │ (None, 100, 128)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 100, 128)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 12800)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 128)            │     1,638,528 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_3           │ (None, 128)            │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 1)              │           129 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,675,329 (6.39 MB)
#  Trainable params: 1,674,625 (6.39 MB)
#  Non-trainable params: 704 (2.75 KB)

# %%
# Train Model 1 – Baseline CNN
history1 = model1.fit(
    X_train, y_train,
    validation_data=(X_test, y_test),
    epochs=60,
    batch_size=64,
    callbacks=get_callbacks(),
    verbose=2
)

loss1, acc1 = model1.evaluate(X_test, y_test, verbose=0)
print(f"\n[Model 1] Test loss: {loss1:.4f} | Test accuracy: {acc1:.4f}")
# Out:
# Epoch 1/60
# 1/1 - 6s - 6s/step - accuracy: 0.5556 - loss: 0.8697 - val_accuracy: 0.8333 - val_loss: 0.4512 - learning_rate: 5.0000e-04
# Epoch 2/60
# 1/1 - 0s - 242ms/step - accuracy: 0.9630 - loss: 0.0950 - val_accuracy: 0.8333 - val_loss: 0.3319 - learning_rate: 5.0000e-04
# Epoch 3/60
# 1/1 - 0s - 225ms/step - accuracy: 0.9815 - loss: 0.0834 - val_accuracy: 0.9167 - val_loss: 0.2811 - learning_rate: 5.0000e-04
# Epoch 4/60
# 1/1 - 0s - 224ms/step - accuracy: 0.9815 - loss: 0.0802 - val_accuracy: 0.9167 - val_loss: 0.2572 - learning_rate: 5.0000e-04
# Epoch 5/60
# 1/1 - 0s - 218ms/step - accuracy: 0.9815 - loss: 0.0475 - val_accuracy: 0.9167 - val_loss: 0.2450 - learning_rate: 5.0000e-04
# Epoch 6/60
# 1/1 - 0s - 230ms/step - accuracy: 0.9815 - loss: 0.0467 - val_accuracy: 0.9167 - val_loss: 0.2390 - learning_rate: 5.0000e-04
# Epoch 7/60
# 1/1 - 0s - 236ms/step - accuracy: 1.0000 - loss: 0.0322 - val_accuracy: 0.9167 - val_loss: 0.2366 - learning_rate: 5.0000e-04
# Epoch 8/60
# 1/1 - 0s - 228ms/step - accuracy: 1.0000 - loss: 0.0348 - val_accuracy: 0.9167 - val_loss: 0.2358 - learning_rate: 5.0000e-04
# Epoch 9/60
# 1/1 - 0s - 227ms/step - accuracy: 1.0000 - loss: 0.0292 - val_accuracy: 0.9167 - val_loss: 0.2354 - learning_rate: 5.0000e-04
# Epoch 10/60
# 1/1 - 0s - 227ms/step - accuracy: 1.0000 - loss: 0.0290 - val_accuracy: 0.9167 - val_loss: 0.2351 - learning_rate: 5.0000e-04
# Epoch 11/60
# 1/1 - 0s - 225ms/step - accuracy: 1.0000 - loss: 0.0304 - val_accuracy: 0.9167 - val_loss: 0.2350 - learning_rate: 5.0000e-04
# Epoch 12/60
# 1/1 - 0s - 217ms/step - accuracy: 1.0000 - loss: 0.0304 - val_accuracy: 0.9167 - val_loss: 0.2356 - learning_rate: 5.0000e-04
# Epoch 13/60
# 1/1 - 0s - 220ms/step - accuracy: 1.0000 - loss: 0.0300 - val_accuracy: 0.9167 - val_loss: 0.2366 - learning_rate: 5.0000e-04
# Epoch 14/60
#
# Epoch 14: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 1/1 - 0s - 219ms/step - accuracy: 1.0000 - loss: 0.0279 - val_accuracy: 0.9167 - val_loss: 0.2381 - learning_rate: 5.0000e-04
# Epoch 15/60
# 1/1 - 0s - 217ms/step - accuracy: 1.0000 - loss: 0.0288 - val_accuracy: 0.9167 - val_loss: 0.2406 - learning_rate: 2.5000e-04
# Epoch 16/60
# 1/1 - 0s - 216ms/step - accuracy: 1.0000 - loss: 0.0286 - val_accuracy: 0.9167 - val_loss: 0.2433 - learning_rate: 2.5000e-04
# Epoch 17/60
# 1/1 - 0s - 225ms/step - accuracy: 1.0000 - loss: 0.0295 - val_accuracy: 0.9167 - val_loss: 0.2459 - learning_rate: 2.5000e-04
# Epoch 18/60
#
# Epoch 18: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 1/1 - 0s - 217ms/step - accuracy: 1.0000 - loss: 0.0296 - val_accuracy: 0.9167 - val_loss: 0.2489 - learning_rate: 2.5000e-04
# Epoch 19/60
# 1/1 - 0s - 230ms/step - accuracy: 1.0000 - loss: 0.0281 - val_accuracy: 0.9167 - val_loss: 0.2526 - learning_rate: 1.2500e-04
# Epoch 19: early stopping
# Restoring model weights from the end of the best epoch: 11.
#
# [Model 1] Test loss: 0.2350 | Test accuracy: 0.9167

# %%
# Section 9: Model 2 - Deep CNN with Global Average Pooling

model2 = Sequential([
    Conv1D(64, 7, activation='relu', padding='same', input_shape=(800, 1)),
    BatchNormalization(),
    MaxPooling1D(2),
    Dropout(0.2),

    Conv1D(128, 5, activation='relu', padding='same'),
    BatchNormalization(),
    MaxPooling1D(2),
    Dropout(0.25),

    Conv1D(256, 3, activation='relu', padding='same'),
    BatchNormalization(),
    MaxPooling1D(2),
    Dropout(0.3),

    Conv1D(256, 3, activation='relu', padding='same'),
    BatchNormalization(),
    MaxPooling1D(2),
    Dropout(0.3),

    GlobalAveragePooling1D(),

    Dense(256, activation='relu', kernel_regularizer=l2(1e-4)),
    Dropout(0.5),
    Dense(1, activation='sigmoid')
], name='Deep_CNN_GAP')

model2.compile(
    optimizer=Adam(learning_rate=0.0003),
    loss='binary_crossentropy',
    metrics=['accuracy']
)

model2.summary()
# Out:
# Model: "Deep_CNN_GAP"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv1d_3 (Conv1D)               │ (None, 800, 64)        │           512 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_4           │ (None, 800, 64)        │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling1d_3 (MaxPooling1D)  │ (None, 400, 64)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_4 (Dropout)             │ (None, 400, 64)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_4 (Conv1D)               │ (None, 400, 128)       │        41,088 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_5           │ (None, 400, 128)       │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling1d_4 (MaxPooling1D)  │ (None, 200, 128)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_5 (Dropout)             │ (None, 200, 128)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_5 (Conv1D)               │ (None, 200, 256)       │        98,560 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_6           │ (None, 200, 256)       │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling1d_5 (MaxPooling1D)  │ (None, 100, 256)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_6 (Dropout)             │ (None, 100, 256)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_6 (Conv1D)               │ (None, 100, 256)       │       196,864 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_7           │ (None, 100, 256)       │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling1d_6 (MaxPooling1D)  │ (None, 50, 256)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_7 (Dropout)             │ (None, 50, 256)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling1d        │ (None, 256)            │             0 │
# │ (GlobalAveragePooling1D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 256)            │        65,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_8 (Dropout)             │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 1)              │           257 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 405,889 (1.55 MB)
#  Trainable params: 404,481 (1.54 MB)
#  Non-trainable params: 1,408 (5.50 KB)

# %%
# Train Model 2 – Deep CNN with GAP
history2 = model2.fit(
    X_train, y_train,
    validation_data=(X_test, y_test),
    epochs=60,
    batch_size=64,
    callbacks=get_callbacks(patience_stop=8, patience_lr=4),
    verbose=2
)

loss2, acc2 = model2.evaluate(X_test, y_test, verbose=0)
print(f"\n[Model 2] Test loss: {loss2:.4f} | Test accuracy: {acc2:.4f}")
# Out:
# Epoch 1/60
# 1/1 - 6s - 6s/step - accuracy: 0.4630 - loss: 0.8021 - val_accuracy: 0.5000 - val_loss: 0.7166 - learning_rate: 3.0000e-04
# Epoch 2/60
# 1/1 - 0s - 367ms/step - accuracy: 0.7963 - loss: 0.5656 - val_accuracy: 0.5000 - val_loss: 0.7159 - learning_rate: 3.0000e-04
# Epoch 3/60
# 1/1 - 0s - 354ms/step - accuracy: 0.9074 - loss: 0.4379 - val_accuracy: 0.5000 - val_loss: 0.7149 - learning_rate: 3.0000e-04
# Epoch 4/60
# 1/1 - 0s - 354ms/step - accuracy: 0.9259 - loss: 0.3214 - val_accuracy: 0.5000 - val_loss: 0.7138 - learning_rate: 3.0000e-04
# Epoch 5/60
# 1/1 - 0s - 333ms/step - accuracy: 0.8704 - loss: 0.3345 - val_accuracy: 0.5000 - val_loss: 0.7135 - learning_rate: 3.0000e-04
# Epoch 6/60
# 1/1 - 0s - 379ms/step - accuracy: 0.9630 - loss: 0.2284 - val_accuracy: 0.5000 - val_loss: 0.7140 - learning_rate: 3.0000e-04
# Epoch 7/60
# 1/1 - 0s - 350ms/step - accuracy: 0.9259 - loss: 0.2683 - val_accuracy: 0.5000 - val_loss: 0.7142 - learning_rate: 3.0000e-04
# Epoch 8/60
# 1/1 - 0s - 339ms/step - accuracy: 0.9259 - loss: 0.2404 - val_accuracy: 0.5000 - val_loss: 0.7142 - learning_rate: 3.0000e-04
# Epoch 9/60
#
# Epoch 9: ReduceLROnPlateau reducing learning rate to 0.0001500000071246177.
# 1/1 - 0s - 380ms/step - accuracy: 0.9259 - loss: 0.2307 - val_accuracy: 0.5000 - val_loss: 0.7140 - learning_rate: 3.0000e-04
# Epoch 10/60
# 1/1 - 0s - 328ms/step - accuracy: 0.9259 - loss: 0.2447 - val_accuracy: 0.5000 - val_loss: 0.7139 - learning_rate: 1.5000e-04
# Epoch 11/60
# 1/1 - 0s - 320ms/step - accuracy: 0.9259 - loss: 0.2228 - val_accuracy: 0.5000 - val_loss: 0.7137 - learning_rate: 1.5000e-04
# Epoch 12/60
# 1/1 - 0s - 378ms/step - accuracy: 0.9259 - loss: 0.2213 - val_accuracy: 0.5000 - val_loss: 0.7134 - learning_rate: 1.5000e-04
# Epoch 13/60
# 1/1 - 0s - 337ms/step - accuracy: 0.9259 - loss: 0.2256 - val_accuracy: 0.5000 - val_loss: 0.7128 - learning_rate: 1.5000e-04
# Epoch 14/60
# 1/1 - 0s - 345ms/step - accuracy: 0.9259 - loss: 0.2092 - val_accuracy: 0.5000 - val_loss: 0.7121 - learning_rate: 1.5000e-04
# Epoch 15/60
# 1/1 - 0s - 360ms/step - accuracy: 0.9259 - loss: 0.1946 - val_accuracy: 0.5000 - val_loss: 0.7114 - learning_rate: 1.5000e-04
# Epoch 16/60
# 1/1 - 0s - 335ms/step - accuracy: 0.9259 - loss: 0.1794 - val_accuracy: 0.5000 - val_loss: 0.7107 - learning_rate: 1.5000e-04
# Epoch 17/60
# 1/1 - 0s - 350ms/step - accuracy: 0.9259 - loss: 0.1958 - val_accuracy: 0.5000 - val_loss: 0.7101 - learning_rate: 1.5000e-04
# Epoch 18/60
# 1/1 - 0s - 332ms/step - accuracy: 0.9259 - loss: 0.1804 - val_accuracy: 0.5000 - val_loss: 0.7094 - learning_rate: 1.5000e-04
# Epoch 19/60
# 1/1 - 0s - 346ms/step - accuracy: 0.9259 - loss: 0.1848 - val_accuracy: 0.5000 - val_loss: 0.7087 - learning_rate: 1.5000e-04
# Epoch 20/60
# 1/1 - 0s - 332ms/step - accuracy: 0.9444 - loss: 0.1542 - val_accuracy: 0.5000 - val_loss: 0.7080 - learning_rate: 1.5000e-04
# Epoch 21/60
# 1/1 - 0s - 372ms/step - accuracy: 0.9259 - loss: 0.1632 - val_accuracy: 0.5000 - val_loss: 0.7073 - learning_rate: 1.5000e-04
# Epoch 22/60
# 1/1 - 0s - 347ms/step - accuracy: 0.9259 - loss: 0.1773 - val_accuracy: 0.5000 - val_loss: 0.7065 - learning_rate: 1.5000e-04
# Epoch 23/60
# 1/1 - 0s - 327ms/step - accuracy: 0.9259 - loss: 0.1585 - val_accuracy: 0.5000 - val_loss: 0.7058 - learning_rate: 1.5000e-04
# Epoch 24/60
# 1/1 - 0s - 330ms/step - accuracy: 0.9259 - loss: 0.1855 - val_accuracy: 0.5000 - val_loss: 0.7052 - learning_rate: 1.5000e-04
# Epoch 25/60
# 1/1 - 0s - 332ms/step - accuracy: 0.9444 - loss: 0.1520 - val_accuracy: 0.5000 - val_loss: 0.7047 - learning_rate: 1.5000e-04
# Epoch 26/60
# 1/1 - 0s - 342ms/step - accuracy: 0.9444 - loss: 0.1575 - val_accuracy: 0.5000 - val_loss: 0.7041 - learning_rate: 1.5000e-04
# Epoch 27/60
# 1/1 - 0s - 375ms/step - accuracy: 0.9259 - loss: 0.1583 - val_accuracy: 0.5000 - val_loss: 0.7034 - learning_rate: 1.5000e-04
# Epoch 28/60
# 1/1 - 0s - 350ms/step - accuracy: 0.9444 - loss: 0.1480 - val_accuracy: 0.5000 - val_loss: 0.7028 - learning_rate: 1.5000e-04
# Epoch 29/60
# 1/1 - 0s - 334ms/step - accuracy: 0.9444 - loss: 0.1368 - val_accuracy: 0.5000 - val_loss: 0.7022 - learning_rate: 1.5000e-04
# Epoch 30/60
# 1/1 - 0s - 383ms/step - accuracy: 0.9444 - loss: 0.1430 - val_accuracy: 0.5000 - val_loss: 0.7017 - learning_rate: 1.5000e-04
# Epoch 31/60
# 1/1 - 0s - 328ms/step - accuracy: 0.9630 - loss: 0.1368 - val_accuracy: 0.5000 - val_loss: 0.7011 - learning_rate: 1.5000e-04
# Epoch 32/60
# 1/1 - 0s - 323ms/step - accuracy: 0.9444 - loss: 0.1455 - val_accuracy: 0.5000 - val_loss: 0.7006 - learning_rate: 1.5000e-04
# Epoch 33/60
# 1/1 - 0s - 390ms/step - accuracy: 0.9630 - loss: 0.1270 - val_accuracy: 0.5000 - val_loss: 0.7000 - learning_rate: 1.5000e-04
# Epoch 34/60
# 1/1 - 0s - 326ms/step - accuracy: 0.9630 - loss: 0.1179 - val_accuracy: 0.5833 - val_loss: 0.6995 - learning_rate: 1.5000e-04
# Epoch 35/60
# 1/1 - 0s - 324ms/step - accuracy: 0.9815 - loss: 0.1187 - val_accuracy: 0.5833 - val_loss: 0.6989 - learning_rate: 1.5000e-04
# Epoch 36/60
# 1/1 - 0s - 378ms/step - accuracy: 0.9630 - loss: 0.1270 - val_accuracy: 0.6667 - val_loss: 0.6983 - learning_rate: 1.5000e-04
# Epoch 37/60
# 1/1 - 0s - 335ms/step - accuracy: 0.9444 - loss: 0.1304 - val_accuracy: 0.5000 - val_loss: 0.6978 - learning_rate: 1.5000e-04
# Epoch 38/60
# 1/1 - 0s - 334ms/step - accuracy: 0.9444 - loss: 0.1218 - val_accuracy: 0.5000 - val_loss: 0.6971 - learning_rate: 1.5000e-04
# Epoch 39/60
# 1/1 - 0s - 385ms/step - accuracy: 0.9815 - loss: 0.1106 - val_accuracy: 0.5833 - val_loss: 0.6964 - learning_rate: 1.5000e-04
# Epoch 40/60
# 1/1 - 1s - 751ms/step - accuracy: 0.9444 - loss: 0.1262 - val_accuracy: 0.5833 - val_loss: 0.6958 - learning_rate: 1.5000e-04
# Epoch 41/60
# 1/1 - 0s - 380ms/step - accuracy: 0.9630 - loss: 0.1242 - val_accuracy: 0.8333 - val_loss: 0.6953 - learning_rate: 1.5000e-04
# Epoch 42/60
# 1/1 - 0s - 328ms/step - accuracy: 0.9630 - loss: 0.1237 - val_accuracy: 0.8333 - val_loss: 0.6947 - learning_rate: 1.5000e-04
# Epoch 43/60
# 1/1 - 0s - 371ms/step - accuracy: 0.9815 - loss: 0.1009 - val_accuracy: 0.8333 - val_loss: 0.6943 - learning_rate: 1.5000e-04
# Epoch 44/60
# 1/1 - 0s - 326ms/step - accuracy: 0.9815 - loss: 0.1095 - val_accuracy: 0.8333 - val_loss: 0.6940 - learning_rate: 1.5000e-04
# Epoch 45/60
# 1/1 - 0s - 342ms/step - accuracy: 0.9444 - loss: 0.1183 - val_accuracy: 0.8333 - val_loss: 0.6936 - learning_rate: 1.5000e-04
# Epoch 46/60
# 1/1 - 0s - 373ms/step - accuracy: 0.9815 - loss: 0.0975 - val_accuracy: 0.8333 - val_loss: 0.6933 - learning_rate: 1.5000e-04
# Epoch 47/60
# 1/1 - 0s - 327ms/step - accuracy: 1.0000 - loss: 0.0839 - val_accuracy: 0.8333 - val_loss: 0.6931 - learning_rate: 1.5000e-04
# Epoch 48/60
# 1/1 - 0s - 331ms/step - accuracy: 1.0000 - loss: 0.0910 - val_accuracy: 0.8333 - val_loss: 0.6929 - learning_rate: 1.5000e-04
# Epoch 49/60
# 1/1 - 0s - 367ms/step - accuracy: 0.9630 - loss: 0.1057 - val_accuracy: 0.8333 - val_loss: 0.6928 - learning_rate: 1.5000e-04
# Epoch 50/60
# 1/1 - 0s - 328ms/step - accuracy: 1.0000 - loss: 0.0847 - val_accuracy: 0.8333 - val_loss: 0.6926 - learning_rate: 1.5000e-04
# Epoch 51/60
# 1/1 - 0s - 326ms/step - accuracy: 1.0000 - loss: 0.0896 - val_accuracy: 0.6667 - val_loss: 0.6926 - learning_rate: 1.5000e-04
# Epoch 52/60
# 1/1 - 0s - 348ms/step - accuracy: 1.0000 - loss: 0.0798 - val_accuracy: 0.6667 - val_loss: 0.6927 - learning_rate: 1.5000e-04
# Epoch 53/60
# 1/1 - 0s - 324ms/step - accuracy: 0.9815 - loss: 0.0910 - val_accuracy: 0.5833 - val_loss: 0.6929 - learning_rate: 1.5000e-04
# Epoch 54/60
#
# Epoch 54: ReduceLROnPlateau reducing learning rate to 7.500000356230885e-05.
# 1/1 - 0s - 325ms/step - accuracy: 0.9815 - loss: 0.0825 - val_accuracy: 0.5000 - val_loss: 0.6932 - learning_rate: 1.5000e-04
# Epoch 55/60
# 1/1 - 0s - 361ms/step - accuracy: 1.0000 - loss: 0.0801 - val_accuracy: 0.5000 - val_loss: 0.6934 - learning_rate: 7.5000e-05
# Epoch 56/60
# 1/1 - 0s - 329ms/step - accuracy: 0.9815 - loss: 0.0997 - val_accuracy: 0.5000 - val_loss: 0.6937 - learning_rate: 7.5000e-05
# Epoch 57/60
# 1/1 - 0s - 318ms/step - accuracy: 0.9815 - loss: 0.0828 - val_accuracy: 0.5000 - val_loss: 0.6941 - learning_rate: 7.5000e-05
# Epoch 58/60
#
# Epoch 58: ReduceLROnPlateau reducing learning rate to 3.7500001781154424e-05.
# 1/1 - 0s - 367ms/step - accuracy: 1.0000 - loss: 0.0673 - val_accuracy: 0.5000 - val_loss: 0.6947 - learning_rate: 7.5000e-05
# Epoch 59/60
# 1/1 - 0s - 322ms/step - accuracy: 0.9815 - loss: 0.0722 - val_accuracy: 0.5000 - val_loss: 0.6953 - learning_rate: 3.7500e-05
# Epoch 59: early stopping
# Restoring model weights from the end of the best epoch: 51.
#
# [Model 2] Test loss: 0.6926 | Test accuracy: 0.6667

# %%
# Section 10: Model 3 - CNN + Bidirectional LSTM Hybrid

model3 = Sequential([
    Conv1D(64, 7, activation='relu', padding='same', input_shape=(800, 1)),
    BatchNormalization(),
    MaxPooling1D(4),  # 800 -> 200
    Dropout(0.2),

    Conv1D(128, 5, activation='relu', padding='same'),
    BatchNormalization(),
    MaxPooling1D(4),
    Dropout(0.25),

    Bidirectional(LSTM(64, return_sequences=False, dropout=0.2, recurrent_dropout=0.1)),

    Dense(64, activation='relu', kernel_regularizer=l2(1e-4)),
    Dropout(0.4),
    Dense(1, activation='sigmoid')
], name='CNN_BiLSTM')

model3.compile(
    optimizer=Adam(learning_rate=0.0003),
    loss='binary_crossentropy',
    metrics=['accuracy']
)

model3.summary()
# Out:
# Model: "CNN_BiLSTM"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv1d_7 (Conv1D)               │ (None, 800, 64)        │           512 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_8           │ (None, 800, 64)        │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling1d_7 (MaxPooling1D)  │ (None, 200, 64)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_9 (Dropout)             │ (None, 200, 64)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_8 (Conv1D)               │ (None, 200, 128)       │        41,088 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_9           │ (None, 200, 128)       │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling1d_8 (MaxPooling1D)  │ (None, 50, 128)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_10 (Dropout)            │ (None, 50, 128)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ bidirectional (Bidirectional)   │ (None, 128)            │        98,816 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 64)             │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_11 (Dropout)            │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 1)              │            65 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 149,505 (584.00 KB)
#  Trainable params: 149,121 (582.50 KB)
#  Non-trainable params: 384 (1.50 KB)

# %%
# Train Model 3 – CNN + Bidirectional LSTM
history3 = model3.fit(
    X_train, y_train,
    validation_data=(X_test, y_test),
    epochs=60,
    batch_size=32,
    callbacks=get_callbacks(patience_stop=8, patience_lr=4),
    verbose=2
)

loss3, acc3 = model3.evaluate(X_test, y_test, verbose=0)
print(f"\n[Model 3] Test loss: {loss3:.4f} | Test accuracy: {acc3:.4f}")
# Out:
# Epoch 1/60
# 2/2 - 13s - 6s/step - accuracy: 0.4815 - loss: 0.7827 - val_accuracy: 0.4167 - val_loss: 0.7142 - learning_rate: 3.0000e-04
# Epoch 2/60
# 2/2 - 0s - 158ms/step - accuracy: 0.6296 - loss: 0.6747 - val_accuracy: 0.5000 - val_loss: 0.7063 - learning_rate: 3.0000e-04
# Epoch 3/60
# 2/2 - 0s - 146ms/step - accuracy: 0.5741 - loss: 0.6653 - val_accuracy: 0.5833 - val_loss: 0.6975 - learning_rate: 3.0000e-04
# Epoch 4/60
# 2/2 - 0s - 155ms/step - accuracy: 0.7963 - loss: 0.5849 - val_accuracy: 0.5833 - val_loss: 0.6888 - learning_rate: 3.0000e-04
# Epoch 5/60
# 2/2 - 0s - 153ms/step - accuracy: 0.8519 - loss: 0.5389 - val_accuracy: 0.6667 - val_loss: 0.6798 - learning_rate: 3.0000e-04
# Epoch 6/60
# 2/2 - 0s - 140ms/step - accuracy: 0.7593 - loss: 0.5082 - val_accuracy: 0.5833 - val_loss: 0.6716 - learning_rate: 3.0000e-04
# Epoch 7/60
# 2/2 - 0s - 142ms/step - accuracy: 0.8148 - loss: 0.4885 - val_accuracy: 0.5833 - val_loss: 0.6641 - learning_rate: 3.0000e-04
# Epoch 8/60
# 2/2 - 0s - 145ms/step - accuracy: 0.8704 - loss: 0.4332 - val_accuracy: 0.5833 - val_loss: 0.6586 - learning_rate: 3.0000e-04
# Epoch 9/60
# 2/2 - 0s - 150ms/step - accuracy: 0.8519 - loss: 0.4097 - val_accuracy: 0.6667 - val_loss: 0.6547 - learning_rate: 3.0000e-04
# Epoch 10/60
# 2/2 - 0s - 143ms/step - accuracy: 0.9074 - loss: 0.3772 - val_accuracy: 0.6667 - val_loss: 0.6516 - learning_rate: 3.0000e-04
# Epoch 11/60
# 2/2 - 0s - 145ms/step - accuracy: 0.8519 - loss: 0.3725 - val_accuracy: 0.7500 - val_loss: 0.6484 - learning_rate: 3.0000e-04
# Epoch 12/60
# 2/2 - 0s - 145ms/step - accuracy: 0.9074 - loss: 0.3597 - val_accuracy: 0.8333 - val_loss: 0.6450 - learning_rate: 3.0000e-04
# Epoch 13/60
# 2/2 - 0s - 156ms/step - accuracy: 0.8704 - loss: 0.3763 - val_accuracy: 0.8333 - val_loss: 0.6414 - learning_rate: 3.0000e-04
# Epoch 14/60
# 2/2 - 0s - 156ms/step - accuracy: 0.8704 - loss: 0.3387 - val_accuracy: 0.8333 - val_loss: 0.6360 - learning_rate: 3.0000e-04
# Epoch 15/60
# 2/2 - 0s - 146ms/step - accuracy: 0.9074 - loss: 0.3026 - val_accuracy: 0.7500 - val_loss: 0.6304 - learning_rate: 3.0000e-04
# Epoch 16/60
# 2/2 - 0s - 154ms/step - accuracy: 0.9259 - loss: 0.3146 - val_accuracy: 0.7500 - val_loss: 0.6253 - learning_rate: 3.0000e-04
# Epoch 17/60
# 2/2 - 0s - 134ms/step - accuracy: 0.9444 - loss: 0.2712 - val_accuracy: 0.7500 - val_loss: 0.6215 - learning_rate: 3.0000e-04
# Epoch 18/60
# 2/2 - 0s - 132ms/step - accuracy: 0.9259 - loss: 0.3219 - val_accuracy: 0.6667 - val_loss: 0.6190 - learning_rate: 3.0000e-04
# Epoch 19/60
# 2/2 - 0s - 142ms/step - accuracy: 0.9259 - loss: 0.2789 - val_accuracy: 0.6667 - val_loss: 0.6164 - learning_rate: 3.0000e-04
# Epoch 20/60
# 2/2 - 0s - 150ms/step - accuracy: 0.9074 - loss: 0.2409 - val_accuracy: 0.6667 - val_loss: 0.6140 - learning_rate: 3.0000e-04
# Epoch 21/60
# 2/2 - 0s - 135ms/step - accuracy: 0.9444 - loss: 0.2243 - val_accuracy: 0.6667 - val_loss: 0.6125 - learning_rate: 3.0000e-04
# Epoch 22/60
# 2/2 - 0s - 142ms/step - accuracy: 0.9259 - loss: 0.2194 - val_accuracy: 0.5833 - val_loss: 0.6106 - learning_rate: 3.0000e-04
# Epoch 23/60
# 2/2 - 0s - 149ms/step - accuracy: 0.9630 - loss: 0.2236 - val_accuracy: 0.5833 - val_loss: 0.6089 - learning_rate: 3.0000e-04
# Epoch 24/60
# 2/2 - 0s - 142ms/step - accuracy: 0.9444 - loss: 0.1804 - val_accuracy: 0.5833 - val_loss: 0.6070 - learning_rate: 3.0000e-04
# Epoch 25/60
# 2/2 - 0s - 142ms/step - accuracy: 0.9259 - loss: 0.2284 - val_accuracy: 0.5833 - val_loss: 0.6052 - learning_rate: 3.0000e-04
# Epoch 26/60
# 2/2 - 0s - 141ms/step - accuracy: 0.9444 - loss: 0.1914 - val_accuracy: 0.5833 - val_loss: 0.6034 - learning_rate: 3.0000e-04
# Epoch 27/60
# 2/2 - 0s - 143ms/step - accuracy: 0.9444 - loss: 0.1706 - val_accuracy: 0.5833 - val_loss: 0.6021 - learning_rate: 3.0000e-04
# Epoch 28/60
# 2/2 - 0s - 135ms/step - accuracy: 0.9444 - loss: 0.1544 - val_accuracy: 0.5833 - val_loss: 0.6011 - learning_rate: 3.0000e-04
# Epoch 29/60
# 2/2 - 0s - 138ms/step - accuracy: 0.9444 - loss: 0.1796 - val_accuracy: 0.5833 - val_loss: 0.6010 - learning_rate: 3.0000e-04
# Epoch 30/60
# 2/2 - 0s - 142ms/step - accuracy: 0.9444 - loss: 0.1620 - val_accuracy: 0.5833 - val_loss: 0.6018 - learning_rate: 3.0000e-04
# Epoch 31/60
# 2/2 - 0s - 133ms/step - accuracy: 0.9815 - loss: 0.1711 - val_accuracy: 0.5833 - val_loss: 0.6025 - learning_rate: 3.0000e-04
# Epoch 32/60
#
# Epoch 32: ReduceLROnPlateau reducing learning rate to 0.0001500000071246177.
# 2/2 - 0s - 130ms/step - accuracy: 1.0000 - loss: 0.1221 - val_accuracy: 0.5833 - val_loss: 0.6017 - learning_rate: 3.0000e-04
# Epoch 33/60
# 2/2 - 0s - 135ms/step - accuracy: 0.9815 - loss: 0.1120 - val_accuracy: 0.5833 - val_loss: 0.6023 - learning_rate: 1.5000e-04
# Epoch 34/60
# 2/2 - 0s - 150ms/step - accuracy: 0.9815 - loss: 0.1083 - val_accuracy: 0.5833 - val_loss: 0.6028 - learning_rate: 1.5000e-04
# Epoch 35/60
# 2/2 - 0s - 133ms/step - accuracy: 0.9815 - loss: 0.1106 - val_accuracy: 0.5833 - val_loss: 0.6032 - learning_rate: 1.5000e-04
# Epoch 36/60
#
# Epoch 36: ReduceLROnPlateau reducing learning rate to 7.500000356230885e-05.
# 2/2 - 0s - 135ms/step - accuracy: 0.9815 - loss: 0.1121 - val_accuracy: 0.5833 - val_loss: 0.6038 - learning_rate: 1.5000e-04
# Epoch 37/60
# 2/2 - 0s - 130ms/step - accuracy: 0.9815 - loss: 0.1151 - val_accuracy: 0.5833 - val_loss: 0.6053 - learning_rate: 7.5000e-05
# Epoch 37: early stopping
# Restoring model weights from the end of the best epoch: 29.
#
# [Model 3] Test loss: 0.6010 | Test accuracy: 0.5833

# %%
# Section 11: Generate predictions for all three models

y_prob1 = model1.predict(X_test, verbose=0).ravel()
y_prob2 = model2.predict(X_test, verbose=0).ravel()
y_prob3 = model3.predict(X_test, verbose=0).ravel()

y_pred1 = (y_prob1 > 0.5).astype(int)
y_pred2 = (y_prob2 > 0.5).astype(int)
y_pred3 = (y_prob3 > 0.5).astype(int)

print("Predictions generated for all three models.")
# Out:
# Predictions generated for all three models.

# %%
# Section 12: Training Curves (Accuracy & Loss)

fig, axes = plt.subplots(2, 3, figsize=(18, 10))
fig.suptitle('Training Curves – All Three Models', fontsize=16, fontweight='bold')

models_info = [
    (history1, 'Model 1: Baseline CNN',    axes[0, 0], axes[1, 0]),
    (history2, 'Model 2: Deep CNN + GAP',  axes[0, 1], axes[1, 1]),
    (history3, 'Model 3: CNN + BiLSTM',    axes[0, 2], axes[1, 2]),
]

for hist, title, ax_acc, ax_loss in models_info:
    epochs_ran = range(1, len(hist.history['accuracy']) + 1)

    # Accuracy subplot
    ax_acc.plot(epochs_ran, hist.history['accuracy'], label='Train', color='steelblue')
    ax_acc.plot(epochs_ran, hist.history['val_accuracy'], label='Val', color='tomato', linestyle='--')
    ax_acc.set_title(title, fontsize=11)
    ax_acc.set_ylabel('Accuracy')
    ax_acc.set_xlabel('Epoch')
    ax_acc.legend()
    ax_acc.grid(alpha=0.3)

    # Loss subplot
    ax_loss.plot(epochs_ran, hist.history['loss'], label='Train', color='steelblue')
    ax_loss.plot(epochs_ran, hist.history['val_loss'], label='Val', color='tomato', linestyle='--')
    ax_loss.set_ylabel('Binary Cross-Entropy Loss')
    ax_loss.set_xlabel('Epoch')
    ax_loss.legend()
    ax_loss.grid(alpha=0.3)

plt.tight_layout()
plt.savefig('training_curves.png', dpi=150, bbox_inches='tight')
plt.show()

# %%
# Section 13: Confusion Matrices

fig, axes = plt.subplots(1, 3, figsize=(18, 5))
fig.suptitle('Confusion Matrices', fontsize=15, fontweight='bold')

preds_and_titles = [
    (y_pred1, 'Model 1: Baseline CNN'),
    (y_pred2, 'Model 2: Deep CNN + GAP'),
    (y_pred3, 'Model 3: CNN + BiLSTM')
]

for ax, (y_pred, title) in zip(axes, preds_and_titles):
    cm = confusion_matrix(y_test, y_pred)

    # Normalize to percentages for straightforward comparison
    cm_pct = cm.astype(float) / cm.sum(axis=1, keepdims=True) * 100

    sns.heatmap(
        cm_pct, annot=True, fmt='.1f', cmap='Blues', ax=ax,
        xticklabels=['Noise', 'P-wave'],
        yticklabels=['Noise', 'P-wave']
    )
    ax.set_xlabel('Predicted label')
    ax.set_ylabel('True label')
    ax.set_title(title)

plt.tight_layout()
plt.savefig('confusion_matrices.png', dpi=150, bbox_inches='tight')
plt.show()

# %%
# Section 14: ROC Curves & AUC

plt.figure(figsize=(8, 6))

models_roc = [
    (y_prob1, 'Baseline CNN', 'steelblue'),
    (y_prob2, 'Deep CNN + GAP', 'tomato'),
    (y_prob3, 'CNN + BiLSTM', 'seagreen')
]

for y_prob, label, color in models_roc:
    fpr, tpr, _ = roc_curve(y_test, y_prob)
    roc_auc = auc(fpr, tpr)
    plt.plot(fpr, tpr, color=color, lw=2, label=f'{label} (AUC = {roc_auc:.4f})')

# Diagonal reference line for a random classifier
plt.plot([0, 1], [0, 1], 'k--', lw=1, label='Random classifier')

plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.02])
plt.xlabel('False Positive Rate', fontsize=12)
plt.ylabel('True Positive Rate', fontsize=12)
plt.title('ROC Curves – Model Comparison', fontsize=14)
plt.legend(loc='lower right', fontsize=11)
plt.grid(alpha=0.3)

plt.savefig('roc_curves.png', dpi=150, bbox_inches='tight')
plt.show()

# %%
# Section 15: Classification Reports (Precision / Recall / F1)

models_reports = [
    ('Model 1 – Baseline CNN', y_pred1),
    ('Model 2 – Deep CNN + GAP', y_pred2),
    ('Model 3 – CNN + BiLSTM', y_pred3),
]

for model_name, y_pred in models_reports:
    print(f"\n{'=' * 55}")
    print(f"  {model_name}")
    print(f"{'=' * 55}")
    print(classification_report(y_test, y_pred, target_names=['Noise', 'P-wave']))
# Out:
# =======================================================
#   Model 1 – Baseline CNN
# =======================================================
#               precision    recall  f1-score   support
#
#        Noise       1.00      0.83      0.91         6
#       P-wave       0.86      1.00      0.92         6
#
#     accuracy                           0.92        12
#    macro avg       0.93      0.92      0.92        12
# weighted avg       0.93      0.92      0.92        12
#
#
# =======================================================
#   Model 2 – Deep CNN + GAP
# =======================================================
#               precision    recall  f1-score   support
#
#        Noise       1.00      0.33      0.50         6
#       P-wave       0.60      1.00      0.75         6
#
#     accuracy                           0.67        12
#    macro avg       0.80      0.67      0.62        12
# weighted avg       0.80      0.67      0.62        12
#
#
# =======================================================
#   Model 3 – CNN + BiLSTM
# =======================================================
#               precision    recall  f1-score   support
#
#        Noise       1.00      0.17      0.29         6
#       P-wave       0.55      1.00      0.71         6
#
#     accuracy                           0.58        12
#    macro avg       0.77      0.58      0.50        12
# weighted avg       0.77      0.58      0.50        12

# %%
# Section 16: Model Comparison Bar Chart

from sklearn.metrics import f1_score, precision_score, recall_score

model_names = ['Baseline CNN', 'Deep CNN + GAP', 'CNN + BiLSTM']
accs = [acc1, acc2, acc3]
f1s = [f1_score(y_test, p) for p in [y_pred1, y_pred2, y_pred3]]
recalls = [recall_score(y_test, p) for p in [y_pred1, y_pred2, y_pred3]]
precisions = [precision_score(y_test, p) for p in [y_pred1, y_pred2, y_pred3]]

x = np.arange(len(model_names))
width = 0.18

fig, ax = plt.subplots(figsize=(14, 8))
bars = [
    ax.bar(x - 1.5 * width, accs, width, label='Accuracy', color='steelblue'),
    ax.bar(x - 0.5 * width, precisions, width, label='Precision', color='seagreen'),
    ax.bar(x + 0.5 * width, recalls, width, label='Recall', color='tomato'),
    ax.bar(x + 1.5 * width, f1s, width, label='F1-Score', color='goldenrod'),
]

for bar_group in bars:
    ax.bar_label(bar_group, fmt='%.3f', padding=4, fontsize=10)

ax.set_ylim(0.5, 1.02)
ax.set_xticks(x)
ax.set_xticklabels(model_names, fontsize=12)
ax.set_ylabel('Score', fontsize=12)
ax.set_title('Model Comparison – Accuracy, Precision, Recall, F1', fontsize=14)
ax.legend(loc='upper center', bbox_to_anchor=(0.5, 1.12), ncol=4, fontsize=11)
ax.grid(axis='y', alpha=0.3)
ax.margins(x=0.05)

plt.tight_layout(rect=[0, 0, 1, 0.93])
plt.savefig('model_comparison.png', dpi=150, bbox_inches='tight')
plt.show()

# %%
# Section 17: Sigmoid Output Distribution

fig, axes = plt.subplots(1, 3, figsize=(18, 5))
fig.suptitle('Predicted Probability Distribution (P-wave class)', fontsize=14)

models_dist = [
    (y_prob1, 'Baseline CNN', 'steelblue'),
    (y_prob2, 'Deep CNN + GAP', 'tomato'),
    (y_prob3, 'CNN + BiLSTM', 'seagreen')
]

# Zip the axes array together with our list of model configurations
for ax, (y_prob, title, color) in zip(axes, models_dist):
    # Separate the predicted probabilities by their actual ground truth labels
    ax.hist(y_prob[y_test == 0], bins=50, alpha=0.6, color='grey', label='True Noise')
    ax.hist(y_prob[y_test == 1], bins=50, alpha=0.6, color=color, label='True P-wave')
    
    ax.axvline(0.5, color='black', linestyle='--', label='Threshold = 0.5')
    ax.set_title(title)
    ax.set_xlabel('Predicted Probability')
    ax.set_ylabel('Count')
    ax.legend(fontsize=9)
    ax.grid(alpha=0.3)

plt.tight_layout()
plt.savefig('prob_distributions.png', dpi=150, bbox_inches='tight')
plt.show()

# %%
# Section 18: Summary Results Table

from sklearn.metrics import roc_auc_score

# Compile all evaluation metrics into a single DataFrame for clean visualization
summary = pd.DataFrame({
    'Model': model_names,
    'Test Loss': [round(loss1, 4), round(loss2, 4), round(loss3, 4)],
    'Accuracy': [round(acc1, 4), round(acc2, 4), round(acc3, 4)],
    'Precision': [round(precision_score(y_test, p), 4) for p in [y_pred1, y_pred2, y_pred3]],
    'Recall': [round(recall_score(y_test, p), 4) for p in [y_pred1, y_pred2, y_pred3]],
    'F1-Score': [round(f1_score(y_test, p), 4) for p in [y_pred1, y_pred2, y_pred3]],
    'AUC-ROC': [round(roc_auc_score(y_test, p), 4) for p in [y_prob1, y_prob2, y_prob3]],
})

print('\n' + '=' * 70)
print('  FINAL RESULTS SUMMARY')
print('=' * 70)
print(summary.to_string(index=False))
print('=' * 70)

# Identify the top-performing architecture based on the AUC-ROC score
best_model_name = summary.loc[summary['AUC-ROC'].idxmax(), 'Model']
print(f'\n-> Best model by AUC-ROC: {best_model_name}')
# Out:
# ======================================================================
#   FINAL RESULTS SUMMARY
# ======================================================================
#          Model  Test Loss  Accuracy  Precision  Recall  F1-Score  AUC-ROC
#   Baseline CNN     0.2350    0.9167     0.8571     1.0    0.9231   1.0000
# Deep CNN + GAP     0.6926    0.6667     0.6000     1.0    0.7500   0.7222
#   CNN + BiLSTM     0.6010    0.5833     0.5455     1.0    0.7059   1.0000
# ======================================================================
#
# -> Best model by AUC-ROC: Baseline CNN
